# %% [markdown]
# # Question 1
# - List all files under guterberg package
# - List all words under file 'austen-persuasion.txt'
# - List all unique words under file 'austen-persuasion.txt'
# - List frequency of each word
# - List Top 10 most frequent words and their frequency

# %%
from nltk.corpus import gutenberg
import operator

# %%
gutenberg.fileids() # Displaying all files under gutenberg package
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
all_words = gutenberg.words('austen-persuasion.txt') # Storing all words under file 'austen-persuasion.txt' in a list
print(all_words) # Displaying all words stored under list
# Out:
# ['[', 'Persuasion', 'by', 'Jane', 'Austen', '1818', ...]

# %%
unique_words = set(all_words) # Filtering and saving all unique words in a list
print(unique_words) # Displaying all unique words under list
# Out:
# {'fact', 'uncommon', 'unbending', 'entertained', 'origin', 'successive', 'valet', 'speeches', 'frank', 'difficulty', 'mistaking', 'incalculable', 'proprieties', 'suffers', 'delusion', 'flirting', 'blows', 'St', 'retrenchments', 'previous', 'Something', 'Louisa', 'promised', 'attendant', 'proof', 'Ireland', 'Belmont', 'ridicule', 'qualified', 'slip', 'real', 'always', 'transient', 'after', 'landlord', 'honours', 'devise', 'unison', 'evade', 'suggest', 'letters', ':', 'violent', 'historian', 'dissuade', 'Spicers', 'conjunctions', 'unpremeditated', 'thanks', 'unable', 'safe', 'darting', 'singing', 'perplexity', 'adverse', 'pretty', 'honest', 'Prettier', 'absolutely', 'boatmen', 'paused', 'communicate', 'violation', 'painting', 'Knowing', 'Ninety', 'dare', 'soothing', 'Hart', 'professionally', 'dancing', 'suitably', 'engaged', 'once', '--;', 'town', 'middle', 'boy', 'shewing', 'fatigues', 'Gay', 'abused', 'haired', 'irritable', 'report', 'generously', 'Men', 'Clay', 'may', 'gift', 'deny', 'sprang', 'plaguing', 'hot', 'This', 'dreaded', 'hysterics', 'self', 'gallant', 'missed', 'beautiful', 'causes', 'blessings', 'repeating', 'haggard', 'fairly', 'hazard', 'It', 'impeaching', 'powers', 'spite', 'foreseeing', 'possess', 'gapes', 'performance', 'spoil', 'indisposed', 'cordial', 'remaining', 'Suppose', 'circle', 'spread', 'saving', 'tone', 'endurable', 'nettles', 'trained', 'seek', 'flagrant', 'condescend', 'trodden', 'quieted', 'committed', 'nice', 'settled', 'attachment', 'decides', 'pierce', 'Events', 'passports', 'laughing', 'cease', 'Cork', 'vague', 'enemy', 'overpowers', 'handwriting', 'sighing', 'extraordinary', 'powder', 'sharing', 'accustomary', 'sell', 'friendship', 'persisted', 'driven', 'alliances', 'works', 'pages', 'dawdling', 'route', 's', 'refrain', 'fare', 'bewitching', 'disagreement', 'farmer', 'needs', 'endured', 'piano', 'terms', 'French', 'clearing', 'rents', 'directing', 'comparatively', 'Walter', 'mildness', 'await', 'felt', 'hollow', 'hey', 'happen', 'sprung', 'changes', 'avoided', 'crossed', 'judgements', 'alienable', 'preserve', 'originals', 'awake', 'whose', 'Anxious', 'might', 'property', 'suspicion', 'deducting', 'direction', 'housekeeping', 'often', 'husband', 'kisses', 'throats', 'hotel', 'provoke', 'hung', 'shortly', 'perpetrated', 'gentlemen', 'nine', 'assenting', 'communications', 'resemble', 'hopelessness', 'finances', 'footing', 'nation', 'unfledged', 'stiles', 'As', 'marrying', 'disposition', 'temper', 'Baronet', 'except', 'Aye', 'Park', 'enquirer', 'stagnation', 'quick', 'indignant', 'bone', 'Pulteney', 'mistress', 'powerful', 'effects', 'trick', 'containing', 'superiors', 'distressed', 'probabilities', 'frightened', 'treating', 'back', 'kindled', 'perceiving', 'rocks', 'Pump', 'grand', 'Benwick', 'nothings', 'sister', 'till', 'misconstruction', 'phoo', 'perceptible', 'brief', 'cautious', 'pursued', 'disinclination', 'faint', 'doted', '12', 'test', 'retrenching', 'procuring', 'infinitely', 'shudderings', 'charity', 'undoubtedly', 'like', 'plead', 'eclat', 'Such', 'Heaven', 'dismembered', 'depends', 'lying', 'were', 'display', 'error', 'given', 'simplest', 'on', 'assertion', 'lies', 'respects', 'periods', 'Trent', 'broke', 'esteemed', 'short', 'allowed', 'admirer', 'despondency', 'bathing', 'twelvemonth', 'ladies', 'actually', 'formed', 'poring', 'shrink', 'hitherto', 'Hers', 'coloured', 'Though', 'renewal', 'warmly', 'perforce', 'submitting', 'cot', 'whisper', 'seniority', 'eligibilities', 'expect', 'James', 'card', 'affectionate', 'eight', 'heir', 'comprehended', 'varying', 'hardship', 'particular', 'argument', 'player', 'rapid', 'sweeps', 'year', 'improvement', 'ingratitude', 'Only', 'power', 'unpersuadable', 'dependence', 'rates', 'trinkets', 'spurned', 'excellent', 'door', 'hospitable', 'tapping', 'quicker', 'deserve', 'destroy', 'thirteen', 'tolerate', 'Union', 'steep', 't', '23', 'chill', 'discerning', 'Ibbotsons', 'Drew', 'alone', 'footsteps', 'dispose', 'wives', 'visitor', 'sent', 'observa ...

# %%
Words_Frequency = {} # Creating an empty dictionary
Word_count = 0 # Creating and assigning value to a count variable
new_list1 = set([x1.lower() for x1 in all_words]) # Creating a list which stores all unique words from words present in 'all_words' list
new_list2 = [x2.lower() for x2 in all_words] # Creating a list which stores all words from words present in 'all_words' list

for x in new_list1: # Looping through all unique words
    for y in new_list2: # Looping through all unique words
        if x == y:
            Word_count = Word_count + 1 # Increamenting the count variable by 1 when if conditind succeeds
            #r1 = new_list2.index(y)
            #new_list2.pop(r1)
    Words_Frequency.update({x:Word_count}) # Adding word alongwith its total frequency in the dictionary
    Word_count = 0 # Ressiging the count variable to 0 for next run of the outer for loop

print(Words_Frequency)  # Displaying word alonwith its frequency
# Out:
# {'dozen': 2, 'calculate': 1, 'consequence': 33, 'accused': 1, 'denial': 1, 'lower': 5, 'revel': 1, 'faces': 3, 'hills': 2, 'sighings': 1, 'sounding': 1, 'yielded': 2, 'stretching': 1, 'dared': 5, 'stepping': 3, 'prevented': 5, 'endowed': 1, 'sultaness': 1, 'contemplate': 2, 'abominates': 1, 'abode': 1, 'straitened': 1, 'contact': 2, 'educated': 2, 'affords': 1, 'half': 60, 'dowager': 4, 'freckles': 6, 'multitude': 1, 'trust': 4, 'discussed': 1, 'cape': 3, 'urging': 1, 'misconstructions': 1, 'renting': 1, 'beauty': 10, 'lead': 2, 'apparent': 7, 'calmness': 4, 'recommendation': 6, 'collect': 2, 'shake': 3, 'tressels': 1, 'jesting': 1, 'protests': 1, 'hundred': 5, 'transformed': 1, 'natured': 2, 'carteret': 12, 'jumped': 2, 'cruelty': 2, 'placid': 1, 'sparingly': 1, 'gross': 1, 'efforts': 2, 'safe': 9, 'song': 4, 'finances': 2, '.--,': 1, 'engagements': 3, 'prematurely': 1, 'limits': 2, 'respectability': 5, 'hasty': 2, 'compelled': 1, 'spine': 1, 'exit': 1, 'sum': 1, 'withdrawing': 1, 'histories': 1, 'its': 72, 'trifling': 1, 'measures': 4, 'innoxious': 2, 'spontaneously': 1, 'vex': 2, 'confusion': 8, 'leaning': 4, 'mindedness': 1, 'finally': 5, 'delusion': 1, 'estimation': 1, 'abide': 1, 'unwilling': 3, 'steeper': 1, 'lisbon': 2, 'channel': 1, 'persuasion': 7, 'regretting': 3, 'considerably': 1, 'directions': 2, 'inverted': 1, 'rivers': 4, 'being': 220, 'gloomy': 1, 'erring': 1, 'esteemed': 2, 'compliment': 4, 'boys': 7, 'wreck': 1, 'ingenuity': 1, 'chattering': 1, 'under': 44, 'saleable': 1, 'pronounced': 2, 'n': 1, 'credible': 1, 'interesting': 13, 'reason': 21, 'distinguish': 6, 'fortify': 1, 'barrier': 1, 'satisfied': 23, 'dearly': 1, 'who': 190, 'privileged': 1, 'nevertheless': 1, 'adverse': 1, 'admirer': 1, 'themselves': 37, 'sore': 3, 'hunting': 2, 'whom': 35, 'parson': 1, 'february': 2, 'arguing': 1, 'leave': 46, 'eligibilities': 1, 'approaching': 1, 'intelligence': 6, 'heats': 1, 'unconsciousness': 1, 'story': 8, 'hesitate': 1, 'admires': 1, 'wont': 1, 'box': 5, 'thoroughfare': 1, 'yestermorn': 1, 'arranger': 1, 'vacancies': 1, 'doted': 1, 'advised': 2, 'mindful': 1, 'alas': 5, 'print': 1, 'firmness': 2, 'secondary': 1, 'springing': 1, 'differently': 11, 'takes': 4, 'embarrass': 1, 'completely': 17, 'virtues': 2, 'youngest': 6, '"': 793, 'securing': 2, 'inconvenience': 4, 'principle': 7, 'affront': 1, 'explanation': 6, 'pretence': 2, 'dimming': 1, 'handsomer': 2, 'estranged': 1, 'worst': 6, 'fancying': 4, 'gown': 1, 'diversified': 1, 'canvass': 1, 'resist': 3, 'according': 1, 'perceive': 4, 'gentle': 7, 'due': 13, 'assist': 5, 'apology': 5, 'dalrymples': 4, 'poisonous': 1, 'follow': 9, 'control': 1, 'speculations': 1, 'chief': 3, 'mirth': 2, 'buildings': 15, 'idly': 1, 'engage': 3, 'fainter': 1, 'nearer': 4, 'retrenchments': 1, 'vext': 1, 'baited': 1, 'rejected': 1, 'merits': 5, 'accurately': 1, 'converse': 2, 'moreover': 6, 'contained': 1, 'invite': 4, 'connexion': 10, 'acknowledgements': 1, 'accomplishment': 1, 'brawn': 1, 'manor': 1, 'cork': 1, 'nights': 2, 'elsewhere': 2, 'nineteen': 6, 'skilful': 1, 'refused': 7, 'peculiar': 5, 'embellishments': 1, 'overbearing': 1, 'mortifying': 2, 'wishers': 1, 'frequent': 3, ',)': 5, 'relenting': 2, 'blowing': 1, 'heartiness': 1, 'employment': 4, 'doing': 28, 'pacing': 1, 'never': 155, 'assure': 25, 'trifled': 1, 'emulating': 1, 'partial': 1, 'suffer': 10, 'unhappy': 4, 'write': 6, 'afternoon': 3, 'lectures': 1, 'whoever': 1, 'testify': 1, 'byron': 3, 'affection': 9, 'outlived': 2, 'reluctance': 1, 'joy': 5, 'blinds': 1, 'brought': 33, 'remnant': 1, 'debts': 1, 'sonnet': 1, 'barouche': 1, 'fling': 1, 'returning': 11, 'believe': 48, 'proficient': 1, 'surname': 1, 'cheer': 1, 'archly': 1, 'accordingly': 6, 'mischief': 4, 'that': 882, 'favourably': 1, 'temptation': 1, '1760': 1, 'above': 6, 'unconvinced': 1, 'estrangement': 2, 'envy': 2, 'shrubberies': 2, 'apologised': 1, 'allowance': 3, 'trafalgar': 1, 'delays': 2, 'startle': 1, 'kneel': 1, 'hates': 1, 'flow': 2, 'law': 8, 'parent ...

# %%
sorted_words = sorted(Words_Frequency.items(), key=operator.itemgetter(1), reverse = True) # Sorting the dictionary value in descending order
print(sorted_words) # Displaying the dictionary sorted on value in descending order
# Out:
# [(',', 6750), ('the', 3329), ('to', 2808), ('and', 2801), ('.', 2741), ('of', 2570), ('a', 1595), ('in', 1389), ('was', 1337), (';', 1290), ('her', 1204), ('had', 1186), ('she', 1146), ('i', 1124), ('it', 1038), ('he', 961), ('be', 950), ('not', 934), ('that', 882), ('as', 809), ('"', 793), ('for', 707), ('but', 664), ('his', 659), ('with', 654), ('you', 628), ('have', 589), ('at', 533), ('all', 530), ("'", 525), ('anne', 497), ('been', 496), ('s', 485), ('him', 467), ('could', 451), ('very', 434), ('they', 433), ('were', 426), ('by', 418), ('which', 416), ('is', 398), ('on', 396), ('."', 369), ('so', 359), ('no', 356), ('would', 355), ('-', 308), ('captain', 303), ('from', 295), ('their', 293), ('mrs', 291), ('elliot', 289), ('there', 286), ('or', 274), ('more', 273), ('them', 270), ('mr', 256), ('!', 253), ('this', 250), ('an', 245), ('than', 243), ('one', 238), ('must', 228), ('when', 228), ('my', 223), ('being', 220), ('only', 219), ('wentworth', 218), ('lady', 216), (',"', 213), ('such', 211), ('do', 210), ('much', 205), ('if', 202), ('any', 199), ('what', 197), ('who', 190), ('me', 188), ('should', 188), ('good', 187), ('little', 176), ('said', 173), ('will', 167), ('might', 166), ('charles', 166), ('well', 163), ('own', 163), ('did', 162), ('herself', 159), ('now', 158), ('never', 155), ('we', 155), ('time', 152), ('sir', 149), ('think', 149), ('russell', 148), ('are', 146), ('other', 143), ('walter', 141), ('nothing', 139), ('mary', 138), ('am', 137), ('some', 136), ('man', 134), ('again', 132), ('great', 130), ('musgrove', 130), ('too', 128), ('know', 127), ('how', 125), ('miss', 125), ('your', 124), (':', 124), ('see', 123), ('most', 123), ('?', 122), ('soon', 122), ('father', 117), ('though', 117), ('before', 116), ('two', 114), ('first', 113), ('quite', 112), ('louisa', 111), ('always', 110), ('without', 108), ('can', 107), ('--', 104), ('every', 102), ('bath', 101), ('has', 100), ('into', 98), ('about', 97), ('made', 96), ('after', 96), ('long', 95), ('himself', 95), ('out', 95), ('house', 94), ('seemed', 93), ('say', 93), ('having', 92), ('up', 91), ('thought', 90), ('however', 89), ('elizabeth', 89), ('?"', 88), ('make', 88), ('go', 88), ('last', 88), ('place', 87), ('better', 87), ('may', 87), ('many', 85), ('same', 84), ('over', 84), ('young', 84), ('found', 83), ('home', 83), ('friend', 83), ('sister', 82), ('room', 82), ('like', 81), ('family', 80), ('felt', 80), ('give', 79), ('way', 78), ('away', 78), ('ever', 78), ('day', 77), ('uppercross', 77), ('come', 75), ('harville', 75), ('feelings', 75), ('henrietta', 74), ('still', 74), ('done', 74), ('sure', 73), ('kellynch', 73), ('its', 72), ('upon', 72), ('those', 72), ('moment', 71), ('even', 71), ('enough', 71), ('then', 70), ('benwick', 70), ('back', 69), ('(', 69), ('off', 69), ('while', 69), ('admiral', 69), ('came', 68), ('smith', 68), ('lyme', 67), ('woman', 67), ('another', 66), ('just', 66), ('clay', 66), ('present', 65), ('our', 65), ('going', 65), ('heard', 65), ('something', 64), ('mind', 64), ('happy', 64), ('here', 63), ('indeed', 63), ('party', 62), ('few', 62), ('down', 61), ('knew', 61), ('acquaintance', 61), ('!"', 61), ('half', 60), ('rather', 60), ('almost', 60), ('morning', 59), ('croft', 58), ('seen', 58), ('wish', 58), ('years', 58), ('yet', 58), ('shall', 57), ('once', 57), ('perhaps', 57), ('dear', 56), ('oh', 56), ('look', 56), ('poor', 55), ('between', 55), ('evening', 55), ('together', 54), ('others', 54), ('hope', 53), ('these', 52), ('ought', 52), ('till', 52), ('where', 51), ('gone', 51), ('take', 51), ('saw', 51), ('life', 49), ('character', 49), ('known', 49), ('anything', 49), ('believe', 48), ('left', 48), ('certainly', 48), ('yes', 48), ('us', 48), ('old', 47), ('cried', 47), ('short', 47), ('side', 47), ('leave', 46), ('since', 45), ('wife', 45), ('deal', 45), ('looking', 45), ('possible', 45), ('near', 45), ('under', 44), ('best', 44), ('feel', 44), ('perfectly', 43), ('interest', 43), ('manner', 43), ('really', 43), ('ri ...

# %%
print(sorted_words[:10]) # Displaying top ten words alongwith its frequency
# Out:
# [(',', 6750), ('the', 3329), ('to', 2808), ('and', 2801), ('.', 2741), ('of', 2570), ('a', 1595), ('in', 1389), ('was', 1337), (';', 1290)]
