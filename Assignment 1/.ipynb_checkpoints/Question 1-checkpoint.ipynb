# %% [markdown]
# # Question 1
# - List all files under guterberg package
# - List all words under file 'austen-persuasion.txt'
# - List all unique words under file 'austen-persuasion.txt'
# - List frequency of each word
# - List Top 10 most frequent words and their frequency

# %%
from nltk.corpus import gutenberg
import operator

# %%
gutenberg.fileids() # Displaying all files under gutenberg package
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
all_words = gutenberg.words('austen-persuasion.txt') # Storing all words under file 'austen-persuasion.txt' in a list
print(all_words) # Displaying all words stored under list
# Out:
# ['[', 'Persuasion', 'by', 'Jane', 'Austen', '1818', ...]

# %%
unique_words = set(all_words) # Filtering and saving all unique words in a list
print(unique_words) # Displaying all unique words under list
# Out:
# {'fact', 'uncommon', 'unbending', 'entertained', 'origin', 'successive', 'valet', 'speeches', 'frank', 'difficulty', 'mistaking', 'incalculable', 'proprieties', 'suffers', 'delusion', 'flirting', 'blows', 'St', 'retrenchments', 'previous', 'Something', 'Louisa', 'promised', 'attendant', 'proof', 'Ireland', 'Belmont', 'ridicule', 'qualified', 'slip', 'real', 'always', 'transient', 'after', 'landlord', 'honours', 'devise', 'unison', 'evade', 'suggest', 'letters', ':', 'violent', 'historian', 'dissuade', 'Spicers', 'conjunctions', 'unpremeditated', 'thanks', 'unable', 'safe', 'darting', 'singing', 'perplexity', 'adverse', 'pretty', 'honest', 'Prettier', 'absolutely', 'boatmen', 'paused', 'communicate', 'violation', 'painting', 'Knowing', 'Ninety', 'dare', 'soothing', 'Hart', 'professionally', 'dancing', 'suitably', 'engaged', 'once', '--;', 'town', 'middle', 'boy', 'shewing', 'fatigues', 'Gay', 'abused', 'haired', 'irritable', 'report', 'generously', 'Men', 'Clay', 'may', 'gift', 'deny', 'sprang', 'plaguing', 'hot', 'This', 'dreaded', 'hysterics', 'self', 'gallant', 'missed', 'beautiful', 'causes', 'blessings', 'repeating', 'haggard', 'fairly', 'hazard', 'It', 'impeaching', 'powers', 'spite', 'foreseeing', 'possess', 'gapes', 'performance', 'spoil', 'indisposed', 'cordial', 'remaining', 'Suppose', 'circle', 'spread', 'saving', 'tone', 'endurable', 'nettles', 'trained', 'seek', 'flagrant', 'condescend', 'trodden', 'quieted', 'committed', 'nice', 'settled', 'attachment', 'decides', 'pierce', 'Events', 'passports', 'laughing', 'cease', 'Cork', 'vague', 'enemy', 'overpowers', 'handwriting', 'sighing', 'extraordinary', 'powder', 'sharing', 'accustomary', 'sell', 'friendship', 'persisted', 'driven', 'alliances', 'works', 'pages', 'dawdling', 'route', 's', 'refrain', 'fare', 'bewitching', 'disagreement', 'farmer', 'needs', 'endured', 'piano', 'terms', 'French', 'clearing', 'rents', 'directing', 'comparatively', 'Walter', 'mildness', 'await', 'felt', 'hollow', 'hey', 'happen', 'sprung', 'changes', 'avoided', 'crossed', 'judgements', 'alienable', 'preserve', 'originals', 'awake', 'whose', 'Anxious', 'might', 'property', 'suspicion', 'deducting', 'direction', 'housekeeping', 'often', 'husband', 'kisses', 'throats', 'hotel', 'provoke', 'hung', 'shortly', 'perpetrated', 'gentlemen', 'nine', 'assenting', 'communications', 'resemble', 'hopelessness', 'finances', 'footing', 'nation', 'unfledged', 'stiles', 'As', 'marrying', 'disposition', 'temper', 'Baronet', 'except', 'Aye', 'Park', 'enquirer', 'stagnation', 'quick', 'indignant', 'bone', 'Pulteney', 'mistress', 'powerful', 'effects', 'trick', 'containing', 'superiors', 'distressed', 'probabilities', 'frightened', 'treating', 'back', 'kindled', 'perceiving', 'rocks', 'Pump', 'grand', 'Benwick', 'nothings', 'sister', 'till', 'misconstruction', 'phoo', 'perceptible', 'brief', 'cautious', 'pursued', 'disinclination', 'faint', 'doted', '12', 'test', 'retrenching', 'procuring', 'infinitely', 'shudderings', 'charity', 'undoubtedly', 'like', 'plead', 'eclat', 'Such', 'Heaven', 'dismembered', 'depends', 'lying', 'were', 'display', 'error', 'given', 'simplest', 'on', 'assertion', 'lies', 'respects', 'periods', 'Trent', 'broke', 'esteemed', 'short', 'allowed', 'admirer', 'despondency', 'bathing', 'twelvemonth', 'ladies', 'actually', 'formed', 'poring', 'shrink', 'hitherto', 'Hers', 'coloured', 'Though', 'renewal', 'warmly', 'perforce', 'submitting', 'cot', 'whisper', 'seniority', 'eligibilities', 'expect', 'James', 'card', 'affectionate', 'eight', 'heir', 'comprehended', 'varying', 'hardship', 'particular', 'argument', 'player', 'rapid', 'sweeps', 'year', 'improvement', 'ingratitude', 'Only', 'power', 'unpersuadable', 'dependence', 'rates', 'trinkets', 'spurned', 'excellent', 'door', 'hospitable', 'tapping', 'quicker', 'deserve', 'destroy', 'thirteen', 'tolerate', 'Union', 'steep', 't', '23', 'chill', 'discerning', 'Ibbotsons', 'Drew', 'alone', 'footsteps', 'dispose', 'wives', 'visitor', 'sent', 'observa ...

# %%
Words_Frequency = {} # Creating an empty dictionary
Word_count = 0 # Creating and assigning value to a count variable
new_list1 = set([x1 for x1 in all_words if x1.isalnum()]) # Creating a list which stores all unique alphanumeric words from words present in 'all_words' list
new_list2 = [x2 for x2 in all_words if x2.isalnum()] # Creating a list which stores all alphanumeric words from words present in 'all_words' list

for x in new_list1: # Looping through all unique alphanumeric words
    for y in new_list2: # Looping through all unique alphanumeric words
        if x == y: # Evaluating if words under 'list1' equals word present under 'list2'
            Word_count = Word_count + 1 # Increamenting the count variable by 1 when if conditind succeeds
            #r1 = new_list2.index(y)
            #new_list2.pop(r1)
    Words_Frequency.update({x:Word_count}) # Adding word alongwith its total frequency in the dictionary
    Word_count = 0 # Ressiging the count variable to 0 for next run of the outer for loop

print(Words_Frequency)  # Displaying word alonwith its frequency
# Out:
# {'credible': 1, 'fact': 15, 'uncommon': 1, 'Accordingly': 1, 'unbending': 1, 'wont': 1, 'entertained': 2, 'origin': 2, 'exquisitely': 1, 'seems': 11, 'expecting': 3, 'receive': 8, 'successive': 2, 'issue': 1, 'parts': 2, 'valet': 1, 'White': 3, 'luck': 7, 'speeches': 1, 'frank': 1, 'hypocrite': 2, 'thinking': 28, 'difficulty': 7, 'mistaking': 1, 'incalculable': 1, 'size': 3, 'intended': 7, 'hesitate': 1, 'withdrawn': 1, 'proprieties': 1, 'suffers': 1, 'penance': 3, 'flirting': 1, 'Z': 1, 'blows': 2, 'bowing': 1, 'St': 3, 'retrenchments': 1, 'down': 61, 'reflections': 2, 'pointing': 4, 'Something': 3, 'Louisa': 111, 'promised': 12, 'risen': 1, 'Captains': 2, 'nights': 2, 'extensive': 2, 'common': 16, 'attendant': 1, 'proof': 15, 'Ireland': 2, 'Belmont': 3, 'ridicule': 2, 'instantaneously': 1, 'readiness': 3, 'winters': 1, 'knowing': 14, 'Strangers': 1, 'grace': 6, 'West': 5, 'qualified': 2, 'pensive': 2, 'real': 22, 'mere': 11, 'always': 109, 'actual': 4, 'transient': 2, 'informs': 1, 'share': 13, 'after': 77, 'Basil': 3, 'landlord': 2, 'honours': 7, 'bed': 5, 'devise': 1, 'evade': 1, 'morrow': 24, 'arrangement': 5, 'suggest': 5, 'letters': 12, 'manly': 1, 'historian': 1, 'disincline': 1, 'has': 100, 'dissuade': 2, 'Spicers': 1, 'this': 200, 'conjunctions': 1, 'inconsistent': 1, 'unpremeditated': 1, 'durable': 2, 'solicitudes': 2, 'thanks': 1, 'examine': 1, 'unable': 7, 'safe': 9, 'notions': 8, 'knife': 1, 'darting': 1, 'sportsmen': 1, 'eye': 24, 'singing': 3, 'credit': 10, 'perplexity': 2, 'married': 23, 'hurricane': 1, 'skirting': 1, 'cherish': 1, 'adverse': 1, 'pretty': 27, 'honest': 1, 'cousinly': 2, 'pin': 2, 'absolutely': 5, 'boatmen': 1, 'paused': 2, 'curricle': 4, 'communicate': 3, 'violation': 1, 'nosegay': 1, 'painting': 1, 'answers': 3, 'orchards': 1, 'exclamation': 1, 'Knowing': 1, 'sameness': 1, 'Indeed': 11, 'Ninety': 1, 'dare': 11, 'soothing': 1, 'Hart': 3, 'prevail': 1, 'become': 13, 'professionally': 1, 'wise': 6, 'labours': 1, 'sparingly': 1, 'dancing': 7, 'tastes': 1, 'deal': 43, 'belonging': 5, 'suitably': 1, 'elevated': 2, 'shelf': 1, 'engaged': 19, 'once': 52, 'politeness': 6, 'rock': 1, 'town': 15, 'middle': 2, 'reverses': 1, 'boy': 14, 'studiously': 2, 'fatigues': 1, 'cliff': 1, 'lofty': 1, 'Gay': 2, 'mountains': 1, 'abused': 2, 'somewhat': 3, 'haired': 2, 'irritable': 1, 'frequent': 3, 'report': 10, 'inadvertence': 1, 'generously': 1, 'fresher': 1, 'comprised': 1, 'amidst': 3, 'Men': 1, 'Poor': 7, 'chamber': 3, 'apparent': 7, 'Clay': 66, 'contents': 1, 'may': 87, 'gift': 1, 'refused': 7, 'ships': 3, 'story': 8, 'deny': 2, 'plaguing': 1, 'clouded': 2, 'frights': 1, 'conclusion': 5, 'disfavour': 1, 'hot': 1, 'caught': 16, 'This': 50, 'dreaded': 2, 'crape': 1, 'hysterics': 1, 'self': 19, 'gallant': 2, 'missed': 2, 'beautiful': 6, 'Lake': 1, 'drawing': 18, 'causes': 1, 'blessings': 3, 'Hear': 1, 'allayed': 1, 'spared': 4, 'repeating': 3, 'haggard': 1, 'word': 32, 'bitterly': 1, 'grief': 3, 'fairly': 4, 'hazard': 1, 'delusion': 1, 'business': 25, 'circumstance': 18, 'It': 181, 'impeaching': 1, 'Lyme': 67, 'powers': 5, 'outweighed': 1, 'spite': 11, 'possess': 2, 'fellow': 18, 'gapes': 1, 'endurances': 1, 'performance': 4, 'teasing': 1, 'spoiled': 1, 'interest': 43, 'along': 13, 'an': 238, 'indisposed': 1, 'cordial': 2, 'remaining': 7, 'longed': 4, 'Suppose': 1, 'midshipmen': 2, 'suppositions': 1, 'circle': 8, 'Granting': 1, 'spread': 5, 'saving': 2, 'tone': 18, 'plea': 1, 'nettles': 1, 'musings': 2, 'hesitated': 2, 'lead': 2, 'aristocratic': 1, 'trained': 1, 'seek': 4, 'acquisition': 1, 'consent': 6, 'trodden': 1, 'observe': 11, 'mad': 1, 'sauntering': 1, 'repose': 3, 'quieted': 1, '16': 2, 'shoot': 1, 'committed': 1, 'clerks': 1, 'nice': 11, 'settled': 22, 'walks': 2, 'inured': 1, 'decides': 1, 'pierce': 1, 'Events': 1, 'clumsy': 1, 'passports': 1, 'unprofitable': 1, 'laughing': 7, 'guide': 2, 'cease': 3, 'and': 2739, 'residents': 1, 'vague': 1, 'enemy': 1, 'overpowers': 2, 'fancied': 10, 'handwriting': 1, ' ...

# %%
sorted_words = sorted(Words_Frequency.items(), key=operator.itemgetter(1), reverse = True) # Sorting the dictionary value in descending order
print(sorted_words) # Displaying the dictionary sorted on value in descending order
# Out:
# [('the', 3120), ('to', 2775), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), ('had', 1177), ('her', 1159), ('I', 1124), ('be', 949), ('not', 926), ('it', 857), ('that', 853), ('she', 819), ('as', 787), ('he', 736), ('for', 695), ('with', 643), ('his', 625), ('have', 583), ('but', 553), ('you', 548), ('at', 519), ('all', 517), ('Anne', 497), ('been', 496), ('s', 485), ('him', 467), ('could', 444), ('were', 426), ('very', 425), ('which', 415), ('by', 411), ('is', 393), ('on', 386), ('would', 351), ('so', 338), ('She', 327), ('they', 323), ('no', 309), ('Captain', 297), ('Mrs', 291), ('from', 290), ('Elliot', 288), ('or', 274), ('their', 273), ('them', 270), ('more', 269), ('Mr', 256), ('than', 243), ('an', 238), ('must', 228), ('He', 225), ('one', 221), ('being', 220), ('Wentworth', 218), ('there', 216), ('only', 214), ('The', 209), ('much', 205), ('this', 200), ('any', 198), ('when', 196), ('such', 196), ('my', 194), ('Lady', 191), ('do', 190), ('me', 188), ('who', 186), ('should', 185), ('It', 181), ('good', 181), ('little', 175), ('said', 173), ('what', 172), ('might', 166), ('Charles', 166), ('own', 163), ('if', 162), ('will', 162), ('herself', 158), ('did', 157), ('never', 153), ('time', 151), ('think', 149), ('Russell', 148), ('now', 144), ('Sir', 144), ('other', 142), ('Walter', 141), ('well', 141), ('are', 141), ('Mary', 138), ('am', 137), ('some', 135), ('man', 133), ('again', 131), ('nothing', 131), ('Musgrove', 130), ('too', 127), ('know', 127), ('Miss', 123), ('see', 123), ('most', 122), ('soon', 121), ('father', 117), ('great', 116), ('before', 113), ('your', 112), ('two', 112), ('first', 112), ('Louisa', 111), ('But', 111), ('we', 110), ('quite', 110), ('They', 110), ('always', 109), ('though', 107), ('without', 106), ('has', 100), ('can', 100), ('Bath', 99), ('into', 98), ('about', 96), ('every', 96), ('made', 96), ('long', 95), ('out', 95), ('himself', 95), ('say', 93), ('seemed', 93), ('up', 90), ('thought', 90), ('having', 90), ('Elizabeth', 89), ('how', 88), ('last', 88), ('may', 87), ('better', 87), ('make', 87), ('go', 87), ('same', 84), ('over', 84), ('however', 83), ('home', 83), ('found', 83), ('young', 83), ('many', 83), ('friend', 83), ('sister', 82), ('felt', 80), ('like', 80), ('You', 80), ('family', 79), ('house', 78), ('way', 78), ('away', 78), ('ever', 78), ('after', 77), ('Uppercross', 77), ('give', 77), ('day', 77), ('Harville', 75), ('feelings', 75), ('room', 75), ('done', 74), ('Henrietta', 74), ('sure', 73), ('still', 72), ('come', 72), ('Kellynch', 72), ('its', 72), ('those', 71), ('moment', 71), ('enough', 71), ('There', 70), ('Benwick', 70), ('back', 69), ('off', 69), ('Smith', 68), ('Lyme', 67), ('came', 67), ('woman', 67), ('even', 67), ('Clay', 66), ('A', 66), ('going', 65), ('heard', 65), ('Admiral', 65), ('just', 65), ('present', 65), ('upon', 64), ('mind', 64), ('happy', 63), ('And', 62), ('another', 62), ('party', 62), ('our', 62), ('down', 61), ('something', 61), ('acquaintance', 61), ('few', 61), ('knew', 61), ('rather', 60), ('almost', 60), ('then', 60), ('morning', 58), ('while', 58), ('years', 58), ('Croft', 58), ('seen', 58), ('wish', 58), ('half', 58), ('yet', 55), ('evening', 55), ('shall', 55), ('look', 54), ('together', 54), ('others', 54), ('Oh', 53), ('hope', 53), ('between', 53), ('once', 52), ('ought', 52), ('indeed', 52), ('gone', 51), ('saw', 51), ('This', 50), ('till', 50), ('place', 50), ('perhaps', 50), ('take', 50), ('dear', 49), ('life', 49), ('character', 49), ('us', 48), ('poor', 48), ('known', 48), ('left', 48), ('anything', 48), ('short', 47), ('side', 47), ('here', 47), ('cried', 47), ('No', 47), ('believe', 47), ('where', 46), ('wife', 45), ('possible', 45), ('looking', 45), ('near', 45), ('We', 45), ('Her', 45), ('leave', 44), ('best', 44), ('certainly', 44), ('under', 44), ('feel', 44), ('deal', 43), ('interest', 43), ('manner', 43), ('these', 43), ('In', 43), ('right', 43), ('since', 43), ('old', 43), ('really', 43), ('perfectly', ...

# %%
print(sorted_words[:10]) # Displaying top ten words alongwith its frequency
# Out:
# [('the', 3120), ('to', 2775), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), ('had', 1177), ('her', 1159), ('I', 1124)]
