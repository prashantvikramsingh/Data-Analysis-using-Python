# %% [markdown]
# # The goal of this analysis is to better understand who is committing terrorists attacks, and how are they carrying out these attacks.

# %%
# Importing the required packages
import os
import glob
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline
from pandas import ExcelWriter

# %%
# Creating the path to read the input file
home_path = os.path.expanduser("~")
data_path = home_path+"\\final\\Data\\*"

# %%
# Looping through each filename in above path and selecting the required file
for file in glob.glob(data_path):
    with open(file, errors='ignore') as source:
        ana_4_data=pd.read_csv(source, low_memory=False, encoding='ISO-8859-1')
ana_4_data.head(2)
# Out:
#         eventid  iyear  imonth  iday         approxdate  extended resolution  \
# 0  2.000000e+11   2001       1     0  January 8-9, 2001         0        NaN
# 1  2.000000e+11   2001       1     1                NaN         0        NaN
#
#    country country_txt  region   ...     \
# 0       45    Colombia       3   ...
# 1      228       Yemen      10   ...
#
#                                             addnotes  \
# 0  Sources imply that the attack may have taken p...
# 1                                                NaN
#
#                                               scite1  \
# 0  "Twenty murdered in attacks across Colombia at...
# 1  âBomb Blast Outside Yemeni News Agency Offic...
#
#                                               scite2  scite3         dbsource  \
# 0  "Colombia violence leaves 35 dead," Agence Fra...     NaN  UMD Schmid 2012
# 1  âAuthorities Arrest Suspects in Aden Bombing...     NaN            CETIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0       -9        -9        0      -9      NaN
# 1       -9        -9        0      -9      NaN
#
# [2 rows x 137 columns]

# %%
# Replacing NAN with 0 in wound column
ana_4_data['nwound'] = ana_4_data['nwound'].fillna(0).astype(int)
# Creating a dataframe by selecting three columns from the main dataframe
sample_DF = ana_4_data[['attacktype1_txt', 'nwound', 'gname']]

# Creating a dataset containing attack count based on type of attack
attack_count = sample_DF[sample_DF.attacktype1_txt != 'Unknown'].groupby(['attacktype1_txt']).size().sort_values(ascending = False).to_frame(name = 'Attack_Count').reset_index()
# Creating a dataset containing attack deaths based on type of attack
attack_death = sample_DF[sample_DF.attacktype1_txt != 'Unknown'].groupby(['attacktype1_txt'])['nwound'].sum().sort_values(ascending = False).to_frame(name = 'Attack_Death').astype(int).reset_index()

# Merging the above two datasets based on type of attack
attack_data = pd.merge(attack_count, attack_death, on = 'attacktype1_txt', how = 'inner')

attack_data

# Writing resultant dataframe to excel file
writer = ExcelWriter('ana_3\\attack_data.xlsx')
attack_data.to_excel(writer,'Sheet1')
writer.save()

# %%
# Creating two subplots
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)

# Plotting the type of attack and its count
ax1 = sns.barplot(x="attacktype1_txt", y="Attack_Count", data=attack_data, ax=ax1, color="#322254") 
ax1.set_title('Attack Count')
ax1.set_xlabel("Type of Attack")
ax1.set_ylabel("Number of Attacks")

# Plotting the type of attack and number of deaths due to the type of attack
ax2 = sns.barplot(x="attacktype1_txt", y="Attack_Death", data=attack_data, ax=ax2, color="#cc5a20") 
ax2.set_title('Attack Deaths')
ax2.set_xlabel("Type of Attack")
ax2.set_ylabel("Number of Deaths")

# Adjusting the graph
plt.subplots_adjust(right=2, top=4)

# Rotating each value on x axis to avoid overlapping
for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=90)

# Displaying count on each bar    
for ax in fig.axes:
    for p in ax.patches:
        ax.annotate(str(round(p.get_height())), (p.get_x() * 1.005, p.get_height() * 1.005), ha='left', va='bottom')

# Saving the plot in png format
plt.savefig('ana_3\\terrgroupcounts.png', bbox_inches='tight')

# %%
# Creating two dataframes to store the number of attacks and number of deaths due terror attacks by specific terrorist groups
Group_Attack_Count = sample_DF[sample_DF.gname != 'Unknown'].groupby(['gname']).size().sort_values(ascending = False).to_frame(name = 'Attack_Count').reset_index()
Group_Attack_Death = sample_DF[sample_DF.gname != 'Unknown'].groupby(['gname'])['nwound'].sum().sort_values(ascending = False).to_frame(name = 'Attack_Death').astype(int).reset_index()

# Merging the above two dataframes based on terrorist groups
Group_Attack_Data = pd.merge(Group_Attack_Count, Group_Attack_Death, on = 'gname', how = 'inner')

# Sorting the above dataframe based on number of deaths
Group_Attack_Data = Group_Attack_Data.sort_values(['Attack_Death'], ascending = False)

# Displaying the top 4 terrorist groups based on number of deaths
Group_Attack_Data.head(4)
# Out:
#                                           gname  Attack_Count  Attack_Death
# 0                                       Taliban          5498         19230
# 1   Islamic State of Iraq and the Levant (ISIL)          2833         17432
# 11                             Al-Qaida in Iraq           635         10238
# 7               Tehrik-i-Taliban Pakistan (TTP)          1153          8269

# %%
# Creating dataframes to store top 4 terrorist groups and their attack methods
Group_Taliban = sample_DF[(sample_DF.gname == 'Taliban') & (sample_DF.attacktype1_txt != 'Unknown')].groupby(['attacktype1_txt']).size().sort_values(ascending = False).to_frame(name = 'Attack_Taliban').reset_index()
Group_ISIL = sample_DF[(sample_DF.gname == 'Islamic State of Iraq and the Levant (ISIL)') & (sample_DF.attacktype1_txt != 'Unknown')].groupby(['attacktype1_txt']).size().sort_values(ascending = False).to_frame(name = 'Attack_ISIL').reset_index()
Group_LTTE = sample_DF[(sample_DF.gname == 'Liberation Tigers of Tamil Eelam (LTTE)') & (sample_DF.attacktype1_txt != 'Unknown')].groupby(['attacktype1_txt']).size().sort_values(ascending = False).to_frame(name = 'Attack_LTTE').reset_index()
Group_Al_Qaida = sample_DF[(sample_DF.gname.str.contains('Al-Qaida')) & (sample_DF.attacktype1_txt != 'Unknown')].groupby(['attacktype1_txt']).size().sort_values(ascending = False).to_frame(name = 'Attack_Al_Qaida').reset_index()

# Writing resultant dataframe to excel file
writer = ExcelWriter('ana_3\\Group_Taliban.xlsx')
Group_Taliban.to_excel(writer,'Sheet1')
writer.save()

writer = ExcelWriter('ana_3\\Group_ISIL.xlsx')
Group_ISIL.to_excel(writer,'Sheet1')
writer.save()

writer = ExcelWriter('ana_3\\Group_LTTE.xlsx')
Group_LTTE.to_excel(writer,'Sheet1')
writer.save()

writer = ExcelWriter('ana_3\\Group_Al_Qaida.xlsx')
Group_Al_Qaida.to_excel(writer,'Sheet1')
writer.save()

# %%
# Creating four subplots
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# Creating plot for terror activities by Taliban
ax1 = sns.barplot(x="attacktype1_txt", y="Attack_Taliban", data=Group_Taliban.head(4), ax=ax1, color="#3ed6e8") 
ax1.set_title('Attacks by Taliban')
ax1.set_xlabel("Type of Attack")
ax1.set_ylabel("Number of Attacks")

# Creating plot for terror activities by ISIL
ax2 = sns.barplot(x="attacktype1_txt", y="Attack_ISIL", data=Group_ISIL.head(4), ax=ax2, color="#6544a9") 
ax2.set_title('Attacks by ISIL')
ax2.set_xlabel("Type of Attack")
ax2.set_ylabel("Number of Attacks")

# Creating plot for terror activities by LTTE
ax3 = sns.barplot(x="attacktype1_txt", y="Attack_LTTE", data=Group_LTTE.head(4), ax=ax3, color="#994e0f") 
ax3.set_title('Attacks by LTTE')
ax3.set_xlabel("Type of Attack")
ax3.set_ylabel("Number of Attacks")

# Creating plot for terror activities by Al_Qaida
ax4 = sns.barplot(x="attacktype1_txt", y="Attack_Al_Qaida", data=Group_Al_Qaida.head(4), ax=ax4, color="#9cd58e") 
ax4.set_title('Attacks by Al_Qaida')
ax4.set_xlabel("Type of Attack")
ax4.set_ylabel("Number of Attacks")

# Adjusting the graph
plt.subplots_adjust(right=2, top=4)

# Rotating each value on x axis to avoid overlapping
for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=15)
    
# Displaying count on each bar    
for ax in fig.axes:
    for p in ax.patches:
        ax.annotate(str(round(p.get_height())), (p.get_x() * 1.005, p.get_height() * 1.005), ha='left', va='bottom')
        
# Saving the plot in png format
plt.savefig('ana_3\\terrgrouppattern.png', bbox_inches='tight')
